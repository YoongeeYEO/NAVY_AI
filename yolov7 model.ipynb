# %%
# %cd /content/yolov7
# Out:
# /content/yolov7

# %%
# !pip install -r /content/yolov7/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.4 MB/s eta 0:00:00
# ...

# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 48.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 kB 26.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.3 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=efb80b8a8ba3696148f9162fa3f8a307e58f60ec6ac3fc003925186bf0219a83
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...

# %%
# !python /content/yolov7/train.py --workers 8 --device 0 --batch-size 16 --epochs 30 --data /content/yolov7/data/coco.yaml --img 640 640 --cfg /content/yolov7/cfg/training/yolov7.yaml --weights '/content/drive/MyDrive/23 해군 AI 경진대회/yolov7_training.pt' --name yolov7-custom --hyp /content/yolov7/data/hyp.scratch.custom.yaml
# Out:
# 2023-06-29 10:21:27.173029: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 10:21:28.060466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16150.875MB)
#
# ...

# %%
# !python /content/yolov7/detect.py --weights /content/yolov7/runs/train/yolov7-custom7/weights/best.pt --conf 0.10 --img-size 640 --source /content/drive/MyDrive/navy_ai/datasets/test/22863.jpg
# Out:
# Namespace(weights=['/content/yolov7/runs/train/yolov7-custom7/weights/best.pt'], source='/content/drive/MyDrive/navy_ai/datasets/test/22863.jpg', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16150.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# %cd /content/yolov7
# Out:
# /content/yolov7

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jCar9pxvjHEPZL8bcR39")
project = rf.workspace("ahmad-hamdan").project("drone_detection-nwflb")
dataset = project.version(1).download("yolov7")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 7.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=2c53a5acbc7601f62a629e0f962e8bf62a73278eabfde9ed098a4ce7b7e8c01c
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
# ...

# %%
# !python /content/yolov7/train.py --workers 8 --device 0 --batch-size 16 --epochs 10 --data /content/yolov7/Drone_detection--1/data.yaml --img 640 640 --cfg /content/yolov7/cfg/training/yolov7.yaml --weights '/content/yolov7/runs/train/yolov7-custom7/weights/best.pt' --name yolov7-custom --hyp /content/yolov7/data/hyp.scratch.custom.yaml
# Out:
# 2023-06-29 10:38:01.222724: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 10:38:02.072947: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16150.875MB)
#
# ...

# %%
# !python /content/yolov7/detect.py --weights /content/yolov7/runs/train/yolov7-custom8/weights/best.pt --conf 0.10 --img-size 640 --source /content/drive/MyDrive/navy_ai/datasets/test/22863.jpg
# Out:
# Namespace(weights=['/content/yolov7/runs/train/yolov7-custom8/weights/best.pt'], source='/content/drive/MyDrive/navy_ai/datasets/test/22863.jpg', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16150.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python /content/yolov7/detect.py --weights /content/yolov7/runs/train/yolov7-custom8/weights/best.pt --conf 0.10 --img-size 640 --source /content/yolov7/runs/detect/exp2/pngtree-drone-flying-over-the-beach-with-a-sunset-image_2876361.png
# Out:
# Namespace(weights=['/content/yolov7/runs/train/yolov7-custom8/weights/best.pt'], source='/content/yolov7/runs/detect/exp2/pngtree-drone-flying-over-the-beach-with-a-sunset-image_2876361.png', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16150.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python /content/yolov7/detect.py --weights /content/yolov7/runs/train/yolov7-custom8/weights/best.pt --conf 0.10 --img-size 640 --source /content/yolov7/runs/04669.jpg
# Out:
# Namespace(weights=['/content/yolov7/runs/train/yolov7-custom8/weights/best.pt'], source='/content/yolov7/runs/04669.jpg', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16150.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
# ...

# %%
# !pwd
# Out:
# /content/yolov7

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="jCar9pxvjHEPZL8bcR39")
project = rf.workspace("sushil-chandra").project("drone-night_v3_nov21")
dataset = project.version(1).download("yolov7")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to drone-Night_V3_Nov21-1 in yolov7pytorch:: 100%|██████████| 3316/3316 [00:00<00:00, 9451.26it/s]

# %%
# !python /content/yolov7/train.py --workers 8 --device 0 --batch-size 16 --epochs 10 --data /content/yolov7/drone-Night_V3_Nov21-1/data.yaml --img 640 640 --cfg /content/yolov7/cfg/training/yolov7.yaml --weights '/content/yolov7/runs/train/yolov7-custom8/weights/best.pt' --name yolov7-custom --hyp /content/yolov7/data/hyp.scratch.custom.yaml
# Out:
# 2023-06-29 11:01:31.745284: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 11:01:32.597726: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16150.875MB)
#
# ...

# %%
# !python /content/yolov7/detect.py --weights /content/yolov7/runs/train/yolov7-custom9/weights/best.pt --conf 0.50 --img-size 640 --source /content/22875.jpg
# Out:
# Namespace(weights=['/content/yolov7/runs/train/yolov7-custom9/weights/best.pt'], source='/content/22875.jpg', img_size=640, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16150.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
# ...
